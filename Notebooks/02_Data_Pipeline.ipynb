# %% [markdown]
# # Building and Using Clean Augmentation Pipeline

# %% [markdown]
# ## Importing data path and modules

# %%
import sys
sys.path.append("../")

from src.data.datamodule import PlantVillageDataModule

# %% [markdown]
# ## Creating the Data Loader

# %%
DATA_DIR = "../data/plantvillage dataset/color"

dm = PlantVillageDataModule(
    data_dir=DATA_DIR,
    batch_size=32,
    img_size=224
)

dm.setup()

# %%
# Setting up the Loaders  
train_loader = dm.train_dataloader()
val_loader = dm.val_dataloader()
test_loader = dm.test_dataloader()

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
print("Test batches:", len(test_loader))
# Out:
# Train batches: 1188
# Val batches: 255
# Test batches: 255

# %% [markdown]
# ## Sanity Check Batch

# %%
images, labels = next(iter(train_loader))

print("Image batch shape:", images.shape)
print("Labels shape:", labels.shape)
# Out:
# Image batch shape: torch.Size([32, 3, 224, 224])
# Labels shape: torch.Size([32])
